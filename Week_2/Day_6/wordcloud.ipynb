# %%
'''
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# !pip install wordcloud
'''
# Out:
# '\n!sudo apt-get install -y fonts-nanum\n!sudo fc-cache -fv\n!rm ~/.cache/matplotlib -rf\n!pip install wordcloud\n'

# %%
from wordcloud import WordCloud
text = open('alice.txt').read()
text
# Out:
# 'Project Gutenberg\'s Alice\'s Adventures in Wonderland, by Lewis Carroll\n\nThis eBook is for the use of anyone anywhere at no cost and with\nalmost no restrictions whatsoever.  You may copy it, give it away or\nre-use it under the terms of the Project Gutenberg License included\nwith this eBook or online at www.gutenberg.org\n\n\nTitle: Alice\'s Adventures in Wonderland\n\nAuthor: Lewis Carroll\n\nPosting Date: June 25, 2008 [EBook #11]\nRelease Date: March, 1994\n[Last updated: December 20, 2011]\n\nLanguage: English\n\n\n*** START OF THIS PROJECT GUTENBERG EBOOK ALICE\'S ADVENTURES IN WONDERLAND ***\n\n\n\n\n\n\n\n\n\n\nALICE\'S ADVENTURES IN WONDERLAND\n\nLewis Carroll\n\nTHE MILLENNIUM FULCRUM EDITION 3.0\n\n\n\n\nCHAPTER I. Down the Rabbit-Hole\n\nAlice was beginning to get very tired of sitting by her sister on the\nbank, and of having nothing to do: once or twice she had peeped into the\nbook her sister was reading, but it had no pictures or conversations in\nit, \'and what 
# ...

# %%
wordcloud = WordCloud().generate(text)
wordcloud
wordcloud.words_
# Out:
# {'said': 1.0,
#  'Alice': 0.7225433526011561,
#  'said Alice': 0.3352601156069364,
#  'little': 0.31213872832369943,
#  'one': 0.29190751445086704,
#  'know': 0.26011560693641617,
#  'went': 0.2398843930635838,
#  'thing': 0.23121387283236994,
#  'time': 0.22254335260115607,
#  'Queen': 0.21965317919075145,
#  'see': 0.1936416184971098,
#  'King': 0.18497109826589594,
#  'well': 0.18208092485549132,
#  'now': 0.17341040462427745,
#  'head': 0.17341040462427745,
#  'began': 0.1676300578034682,
#  'way': 0.16473988439306358,
#  'Hatter': 0.16473988439306358,
#  'Mock Turtle': 0.16184971098265896,
#  'say': 0.15895953757225434,
#  'Gryphon': 0.15895953757225434,
#  'think': 0.1531791907514451,
#  'quite': 0.15028901734104047,
#  'much': 0.14739884393063585,
#  'first': 0.14739884393063585,
#  'thought': 0.14450867052023122,
#  'go': 0.14450867052023122,
#  'come': 0.13872832369942195,
#  'never': 0.13583815028901733,
#  'voice': 0.1329479768786127,
#  'looked': 0.13005780346820808,
# ...

# %%
import matplotlib.pyplot as plt
wordcloud = WordCloud(max_words=100).generate(text)
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis=('off')
plt.show()

# %%
from wordcloud import STOPWORDS
STOPWORDS
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
# ...

# %%
type(STOPWORDS)
# Out:
# set

# %%
STOPWORDS.add('said')
print(STOPWORDS)
# Out:
# {'there', 'then', "they're", 'i', 'until', 'own', 'just', 'at', 'shall', 'or', 'as', 'my', 'they', "you'd", "i've", "don't", 'other', 'because', 'some', 'if', 'when', 'therefore', 'a', "hasn't", 'we', "we're", "he's", 'was', 'too', 'out', "haven't", 'yourselves', "hadn't", "they've", 'yours', 'against', 'com', 'after', 'very', 'over', 'few', 'further', "he'll", "there's", "i'm", 'only', 'ever', "they'd", 'of', "mustn't", 'this', 'you', 'do', 'her', 'that', "they'll", "won't", 'the', 'ours', 'on', "can't", 'like', 'than', 'themselves', 'else', 'ought', "doesn't", 'theirs', 'them', 'me', 'yourself', 'get', 'she', 'itself', 'same', "i'll", "when's", 'would', 'doing', "where's", 'hence', 'however', 'again', "couldn't", 'above', 'is', "weren't", 'which', 'while', 'had', 'whom', "isn't", "i'd", "here's", 'his', "you're", 'through', 'during', 'herself', 'been', 'below', 'how', 'could', 'him', "why's", 'also', "he'd", 'most', "you'll", "let's", 'all', 'nor', 'so', 'http', "didn't", "we'd", '
# ...

# %%
wordcloud = WordCloud(max_words=50,font_path='/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf',stopwords=STOPWORDS).generate(text)
plt.figure(figsize=(10,8))
plt.axis=('off')
plt.imshow(wordcloud)
plt.show()

# %%
from PIL import Image
import numpy as np

# %%
word_mask=np.array(Image.open('alice_mask.png'))
word_mask
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
wordcloud=WordCloud(max_words=100,
 font_path='/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf',stopwords=STOPWORDS,mask=word_mask,background_color='ivory').generate(text)
plt.figure(figsize=(10,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
word_mask=np.array(Image.open('tree.jpg'))
word_mask
# Out:
# array([[[238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
wordcloud=WordCloud(max_words=100,
 font_path='/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf',stopwords=STOPWORDS,mask=word_mask,background_color='ivory').generate(text)
plt.figure(figsize=(5,3))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
user_agent = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36"}
from bs4 import BeautifulSoup
import requests
import time
questions = []

# %%
for i in range(1, 30):
#페이지네이션 적용
 res = requests.get("https://qna.programmers.co.kr/?page={}".format(i), user_agent)
 soup = BeautifulSoup(res.text, "html.parser")
 ul_tags = soup.find_all("ul", "question-tags")
 for ul in ul_tags:
  li_tags = ul.find_all("li")
  for li in li_tags:
    #빈칸이 너무많아 strip()으로 처리
    questions.append(li.text.strip())
 time.sleep(0.5)

# %%
#!pip install konlpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 31.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 27.9 MB/s eta 0:00:00
# ...

# %%
# 횟수를 기반으로 딕셔너리 생성
from collections import Counter
# 문장에서 명사를 추출하는 형태소 분석 라이브러리
from konlpy.tag import Hannanum
words = []
hannanum = Hannanum()
#문장이 아니라 지금은 리스트이기 때문에 for문을 돌면서 각각의 형태소를 분석.
for question in questions:
 nouns = hannanum.nouns(question) #한 번 반복할 때 나오는 명사들
 words += nouns #word에 누적.

# counter를 이용해 각 단어의 개수.
counter = Counter(words)
counter
# Out:
# Counter({'c++': 82,
#          'python3': 14,
#          'c#': 14,
#          'c++표준': 2,
#          'cv2': 3,
#          '2010': 1,
#          's3': 1,
#          'software_development': 1,
#          'win32': 1,
#          'html5': 4,
#          '문': 6,
#          '에러': 1,
#          '403clienterror': 1,
#          '8': 2,
#          'word2vec': 2,
#          '3': 1,
#          'psycopg2': 1,
#          'dev-c++': 2,
#          'python3.': 1,
#          '6.': 1,
#          '1': 1,
#          '2.': 2,
#          '7': 2,
#          'pyside2': 3,
#          'pyqt5': 4,
#          '2d': 1,
#          'sqlite3': 2,
#          '3d': 1,
#          '용량': 1,
#          'c++11': 1,
#          'log4j': 1})

# %%
#시각화에 쓰이는 라이브러리
import matplotlib.pyplot as plt
from wordcloud import WordCloud
wordcloud = WordCloud(
 font_path = '/usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf',
 height = 1000,
 width=1000
)
plt.axis('off')
img = wordcloud.generate_from_frequencies(counter)
plt.imshow(img)

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
url='https://n.news.naver.com/article/009/0005234817?sid=104'
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')
elements = soup.select('article')
result=[]
for element in elements:
    result.append(element.text)

# %%
from wordcloud import STOPWORDS
stopwords=['이','에서','난','은','로','을','사진출처','으로','해','연합뉴스','것으로']
for stopword in stopwords:
    STOPWORDS.add(stopword)
print(STOPWORDS)
# Out:
# {'there', 'then', "they're", 'i', 'until', 'own', 'just', '연합뉴스', 'at', 'shall', 'or', 'as', 'my', 'they', "you'd", '사진출처', "i've", "don't", 'other', 'because', '난', 'some', 'if', 'when', 'therefore', 'a', "hasn't", 'we', "we're", "he's", 'was', 'too', 'out', "haven't", 'yourselves', "hadn't", "they've", 'yours', 'against', 'com', 'after', 'very', 'over', 'few', '로', 'further', "he'll", "there's", "i'm", 'only', 'ever', "they'd", 'of', "mustn't", 'this', 'you', 'do', 'her', 'that', "they'll", "won't", '해', 'the', 'ours', 'on', "can't", '에서', 'like', 'than', '을', 'themselves', 'else', 'ought', "doesn't", 'theirs', 'them', 'me', '것으로', 'yourself', 'get', 'she', 'itself', 'same', "i'll", "when's", 'would', 'doing', "where's", 'hence', 'however', 'again', "couldn't", 'above', 'is', "weren't", 'which', 'while', 'had', 'whom', "isn't", "i'd", "here's", 'his', "you're", 'through', 'during', 'herself', 'been', 'below', 'how', 'could', 'him', "why's", 'also', "he'd", 'most', "you'll", '이', "l
# ...

# %%
from importlib import reload
plt=reload(plt)

# %%
wordcloud = WordCloud(max_words=50,font_path='/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf').generate(result[0])
plt.figure(figsize=(10,8))
plt.imshow(wordcloud)
plt.axis=('off')
plt.show()

# %%
wordcloud=WordCloud(max_words=100,
                    font_path='/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf',
                    stopwords=STOPWORDS).generate(result[0])
plt.figure(figsize=(10,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
from PIL import Image
import numpy as np
word_mask=np.array(Image.open('korea.jpg'))
word_mask
wordcloud=WordCloud(max_words=100,
                    font_path='/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf',
                    stopwords=STOPWORDS,
                    mask=word_mask,background_color='ivory')
img=wordcloud.generate(result[0])
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
