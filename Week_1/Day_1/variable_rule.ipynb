# %% [markdown]
# # 변수 규칙

# %% [markdown]
# # Python의 변수 규칙
# ## 1-2
# ### 1-2-1
#
# 문자, 숫자, 밑줄 등을 포함 할 수 있다.
# 숫자는 제일 처음에 나올 수 없다.

# %% [markdown]
# 대소문자를 구분한다

# %%
friend = 1
Friend = 10

# %%
friend, Friend
# Out:
# (1, 10)

# %% [markdown]
# 숫자형

# %%
year = 2023
month = 12
print(year, month)
# Out:
# 2023 12

# %%
type(year)
# Out:
# int

# %% [markdown]
# 진법

# %%
0o10 # 8진수
# Out:
# 8

# %%
0x10 # 16진수
# Out:
# 16

# %%
oct(38), hex(38), bin(38) # oct: 10진수, hex: 16진수, bin: 2진수
# Out:
# ('0o46', '0x26', '0b100110')

# %%
type(1), type(3.14)
# Out:
# (int, float)

# %%
# 원의 넓이를 구하기
r = 2
circle_area = 3.14 * (r ** 2)
print(circle_area)
# Out:
# 12.56

# %%
# 삼각형의 면적구하기
x = 3
y = 4
triangle_area = x * y / 2
print(triangle_area)
# Out:
# 6.0

# %%
# 문자형 실습

'Hello Python'
# Out:
# 'Hello Python'

# %%
'Welcome to "Python World"' # 쌍따음표를 이용하는 경우
# Out:
# 'Welcome to "Python World"'

# %%
long_text = '''
항상 태양을 바라 보아라
그리하면 너는 그림자를 볼 수 없을 것이다.

- 헬렌켈러-
'''

print(long_text)
# Out:
# 항상 태양을 바라 보아라
# 그리하면 너는 그림자를 볼 수 없을 것이다.
#
# - 헬렌켈러-

# %%
# 이스케이프 문자

print('\t뉴진스\n')
print('\t다니엘\t해린\t민지\t')
# Out:
# 	뉴진스
#
# 	다니엘	해린	민지

# %%
'py' 'thon'
# Out:
# 'python'

# %%
'py'+'thon'
# Out:
# 'python'

# %%
'py'*3
# Out:
# 'pypypy'

# %%
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------

# %%
a = 'Python'

# %%
#Slice
a = 'Welcome to Python World'

# %%
a[0:7]
# Out:
# 'Welcome'

# %%
a[7:]
# Out:
# ' to Python World'

# %%
a[0:18]
# Out:
# 'Welcome to Python '

# %%
a[0:18:2]
# Out:
# 'Wloet yhn'
