# %% [markdown]
# http 통신, 이미지 처리

# %%
import requests   #requests : 웹 통신 담당

# %%
response = requests.get('http://www.naver.com')
#response.text

# %%
#<Response [200]> -> 응답 성공 알림

# %%
from PIL import Image   #PIL : Image 처리 담당
from io import BytesIO    #io : input, output 담당

# %%
response = requests.get('https://th.bing.com/th/id/OIP.ZwsnZ6yxBpYyg0YXAimNeQHaE7?w=272&h=181&c=7&r=0&o=5&dpr=1.3&pid=1.7')

# %%
#response.content #결과값 -> 16진수 데이터 인코딩

# %%
BytesIO(response.content) #image 코드를 byte 코드로 복호화

# %%
image = Image.open(BytesIO(response.content))

# %%
Image.open(BytesIO(requests.get('https://th.bing.com/th/id/OIP.ZwsnZ6yxBpYyg0YXAimNeQHaE7?w=272&h=181&c=7&r=0&o=5&dpr=1.3&pid=1.7').content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=353x235>

# %%
#github open ai 'https://github.com/openai/openai-python'
